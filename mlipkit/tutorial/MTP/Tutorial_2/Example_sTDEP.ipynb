# %%
import numpy as np
from ase.io import read
from ase.build import make_supercell
from pathlib import Path

from my_utils.utils_stdep import launch_stdep

from mlipkit.MTP.mtp_model import MTP_model

temperature = 200 
ucell = read('T200K_unitcell.json')
scell_mat = np.eye(3) * 4

pot_files = {'potential_file': '/Users/samuel/Work/ML/MoS2/mlip/mtp_6/training/pot.mtp'}
mlip_bin = '/Users/samuel/Work/codes/mlip-2/build1/mlp'
bin_pref = 'mpirun -n 6'

mlip_model = MTP_model(root_dir='pre_trained_model', 
                       name='MTP_model', 
                       pre_trained=True, 
                       pre_trained_pot_filepaths=pot_files)

launch_stdep(root_dir = './',
                ucell=ucell,
                make_supercell = True,
                scell_mat=scell_mat,
                scell=None,
                temperature = temperature,
                preexisting_ifcs = False,
                preexisting_ifcs_path=None,
                max_freq = 15,
                quantum = True,
                first_order = False,
                displ_threshold_firstorder = 0.0001,
                max_iterations_first_order = 20,
                rc2 = 4,
                niters = 5,
                nconfs = [4, 8, 10, 20, 40],
                remove_infiles = True,
                mlip_bin = mlip_bin,
                bin_prefix = bin_pref,
                mlip_model=mlip_model)
# Out:
# ++++++++++++++++++++++++++++++++++++++
# ----------- sTDEP launched -----------
# ++++++++++++++++++++++++++++++++++++++
# ====== ITERATION n. 1 ======
# ====== ITERATION n. 2 ======
# **** Extraction of IFCs with TDEP ****
# Here are the parameters for the IFCs extraction:
# 	2nd-order cutoff: 4 Angstroms
# 	Temperature: 200
# 	No 3rd-order interactions
# 	No 4th-order interactions
# 	Binary prefix: mpirun -n 6
# 	Polar correction (LO-TO): no
# 	Stride: 1
# ****** Extraction of IFCs done! ******
# ====== ITERATION n. 3 ======
# **** Extraction of IFCs with TDEP ****
# Here are the parameters for the IFCs extraction:
# 	2nd-order cutoff: 4 Angstroms
# 	Temperature: 200
# 	No 3rd-order interactions
# 	No 4th-order interactions
# 	Binary prefix: mpirun -n 6
# 	Polar correction (LO-TO): no
# 	Stride: 1
# ****** Extraction of IFCs done! ******
# ====== ITERATION n. 4 ======
# **** Extraction of IFCs with TDEP ****
# Here are the parameters for the IFCs extraction:
# 	2nd-order cutoff: 4 Angstroms
# 	Temperature: 200
# 	No 3rd-order interactions
# 	No 4th-order interactions
# 	Binary prefix: mpirun -n 6
# 	Polar correction (LO-TO): no
# 	Stride: 1
# ****** Extraction of IFCs done! ******
# ====== ITERATION n. 5 ======
# **** Extraction of IFCs with TDEP ****
# Here are the parameters for the IFCs extraction:
# 	2nd-order cutoff: 4 Angstroms
# 	Temperature: 200
# 	No 3rd-order interactions
# 	No 4th-order interactions
# 	Binary prefix: mpirun -n 6
# 	Polar correction (LO-TO): no
# 	Stride: 1
# ****** Extraction of IFCs done! ******
